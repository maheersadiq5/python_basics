# %%
city name enter

# %%
city=input("hey,enter your city name :")
print("welcome to city",city)
# Out:
# hey,enter your city name :gujar khan
# welcome to city gujar khan

# %%
sum of two number

# %%
num1 = int(input("enter 1st number:"))
num2 = int(input("enter 2nd number"))
sum = num1+num2
print(sum)
# Out:
# enter 1st number:7
# enter 2nd number5
# 12
