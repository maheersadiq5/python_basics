# %%
DICTIONARY

# %%
student={"name":"maha","age":21,"sem":"2nd"}
print(student)
del student["name"]
print(student)
# Out:
# {'name': 'maha', 'age': 21, 'sem': '2nd'}
# {'age': 21, 'sem': '2nd'}

# %%
DICTIONARY

# %%
fruit ={}
fruit["name"] ="MANGO"
fruit["color"] ="yellow"
fruit["taste"] ="sweet"
print(fruit)
del fruit["name"]
print(fruit)
# Out:
# {'name': 'MANGO', 'color': 'yellow', 'taste': 'sweet'}
# {'color': 'yellow', 'taste': 'sweet'}
