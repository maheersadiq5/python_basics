# %% [markdown]
# print in python

# %%
print("my namw is maheer sadiq")
# Out:
# my namw is maheer sadiq

# %%
print("2.5")
# Out:
# 2.5

# %%
name="ali"
print("my name is:",name)# this is print type this is multi line comment#
print(type(name))
# Out:
# my name is: ali
# <class 'str'>

# %%
old= False
age = 5
name="maha"
print(type(old))
print(type(age))
print(type(name))
# Out:
# <class 'bool'>
# <class 'int'>
# <class 'str'>

# %%
a=9
b=88
print(not(a>b))
# Out:
# True

# %%
a="maha"

print(type(ab))
# Out:
# <class 'str'>

# %%
input("your name is")
# Out:
# your name isali
# 'ali'

# %%
name=(input(type("your name is")))
print ("welcome",name)
# Out:
# <class 'str'>maha
# welcome maha

# %% [markdown]
# DICTIONARY IN PYTHON

# %%
student={"name":"maha","age":21,"course":"python"}
print(student)
del student["age"]
print(student)
# Out:
# {'name': 'maha', 'age': 21, 'course': 'python'}
# {'name': 'maha', 'course': 'python'}

# %% [markdown]
# empty dictionary

# %%
student={}
student ["name"]="ali"
student["age"]=21
student["sem"]="2nd"
print(student)

del student["name"]
print(student)
# Out:
# {'name': 'ali', 'age': 21, 'sem': '2nd'}
# {'age': 21, 'sem': '2nd'}
